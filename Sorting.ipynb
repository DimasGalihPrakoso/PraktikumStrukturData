# %%
def bubble_sort(arr):
  n = len(arr)
  for i in range (n - 1):
    for j in range(n - i - 1):
      if arr[j] > arr[j + 1]:
        arr[j], arr[j + 1] = arr[j + 1], arr[j]
  return arr

#Contoh penggunaaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = bubble_sort(data.copy()) #menggunakan copy agar data asli tidak  berubah
print("Data sebelum disorting:", data)
print("Data setelah Bubble Sort:", sorted_data)
# Out:
# Data sebelum disorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Bubble Sort: [11, 12, 22, 25, 34, 64, 90]

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
              min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr
#Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = selection_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Selection Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Selection Sort: [11, 12, 22, 25, 64]

# %%
def insertion_sort(arr):
    n = len(arr)
    for i in range(1, n):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
              arr[j + 1] = arr[j]
              j -= 1
        arr[j + 1] = key
    return arr
#Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = insertion_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Insertion Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Insertion Sort: [11, 12, 22, 25, 34, 64, 90]

# %%
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left_half = arr[:mid]
        right_half = arr[mid:]

        merge_sort(left_half)
        merge_sort(right_half)

        i = j = k = 0
        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
                k += 1

            while i < len(left_half):
                arr[k] = left_half[i]
                i += 1
                k += 1

            while j < len(right_half):
                arr[k] = right_half[j]
                j += 1
                k += 1

        return arr
#Contoh penggunaan
data = [64, 25, 12, 22, 11] #Changed from tuple to list
sorted_data = merge_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Merge Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Merge Sort: [11, 25, 64, 12, 22]

# %%
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]

    return quick_sort(left) + middle + quick_sort(right)

#Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = quick_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Quick Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Quick Sort: [11, 12, 22, 25, 64]

# %%
#LATIHAN/TUGAS

#Optimasi Pencarian Produk di Marketplace
def selection_sort_produk(data):
    n = len(data)

    for i in range(n - 1):
        min_index = i

        for j in range(i + 1, n):
            if data[j]['harga'] < data[min_index]['harga']:
                min_index = j

        # Tukar posisi
        data[i], data[min_index] = data[min_index], data[i]

    return data


#Data produk
produk = [
    {"nama": "Laptop", "harga": 8500000},
    {"nama": "Mouse", "harga": 150000},
    {"nama": "Keyboard", "harga": 300000},
    {"nama": "Monitor", "harga": 2500000},
    {"nama": "Headset", "harga": 450000}
]

#Proses sorting
hasil = selection_sort_produk(produk.copy())

print("Data sebelum sorting:")
for p in produk:
    print(p["nama"], "-", p["harga"])

print("\nData setelah sorting (harga termurah ke termahal):")
for p in hasil:
    print(p["nama"], "-", p["harga"])
# Out:
# Data sebelum sorting:
# Laptop - 8500000
# Mouse - 150000
# Keyboard - 300000
# Monitor - 2500000
# Headset - 450000
#
# Data setelah sorting (harga termurah ke termahal):
# Mouse - 150000
# Keyboard - 300000
# Headset - 450000
# Monitor - 2500000
# Laptop - 8500000

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr


#Data produk
harga_produk = [8500000, 150000, 300000, 2500000, 450000]

#Proses sorting
sorted_harga = selection_sort(harga_produk.copy())

print("Harga sebelum sorting:", harga_produk)
print("Harga setelah sorting (termurah ke termahal):", sorted_harga)
# Out:
# Harga sebelum sorting: [8500000, 150000, 300000, 2500000, 450000]
# Harga setelah sorting (termurah ke termahal): [150000, 300000, 450000, 2500000, 8500000]
